# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
from os import walk
from os import makedirs
from skimage.color import label2rgb
from skimage.measure import label, regionprops
from skimage.segmentation import clear_border
# %matplotlib inline

# %% [markdown]
# Creating an class that will contain all bale paths

# %%
class balefiles:
    def __init__ (self,path):
        self.main = path
        self.paths = []
        self.pathfiles = []
        self.names = []
        self.files = {}
        for (dirpath, dirnames, filenames) in walk(path):
            self.paths.extend(dirnames)
            break
        if 'Segmented' in self.paths:
            self.paths.remove('Segmented')
        self.paths.sort()
        self.paths = [p for p in self.paths]
    
    def files_in_path (self,path):
        temp = []
        for (dirpath, dirnames, filenames) in walk(self.main+path):
            temp.extend(filenames)
            break
        temp = [file for file in temp if '.JPG' in file]
        temp.sort()
        self.files[path]=temp
        return temp
    
    def getall (self):
        self.files = {}
        for path in self.paths:
            self.names.append(self.files_in_path(path))
        
        for i in range(len(self.paths)):
            self.pathfiles.append([self.main+self.paths[i]+'/'+name for name in self.files[self.paths[i]]])

# %%
def extract_bales(img):
    img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(img_gray,(45,3),0)
    blur = cv2.GaussianBlur(blur,(45,3),0)
    histeq = cv2.equalizeHist(blur)
    ret3,th3 = cv2.threshold(histeq,254,255,cv2.THRESH_BINARY)
    erosion = cv2.erode(th3,cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(20,20)),iterations = 1)
    final = cv2.dilate(erosion,cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(25,25)),iterations = 7)
    final = clear_border(final)
    return final

# %%
def rework(folder,j,db,mask,means,stds,img,rw=0):
    remove_flag=False
    label_image= label(mask)
    la,count = np.unique(label_image,return_counts=True)
    la = la[1:]
    count = count[1:]
    for i in range(len(count)):
        if (count[i]>(means[folder]+stds[folder]) or count[i]<(means[folder]-stds[folder])):
            #print(img.shape)
            rw +=1
            print('data/'+db.paths[folder]+'/'+db.names[folder][j])
            print('rework: ',rw)
            remove_flag=True
            mask = cv2.dilate(mask,cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(100,100)),iterations = 1)
            inv_mask=255-(label_image==la[i])*mask
            new_img = cv2.bitwise_and(img,img,mask=inv_mask)
            final = extract_bales(new_img)
            np.save('data/'+str(folder)+'/masks/M-'+db.names[folder][j][:-4],final)
            res = np.hstack((new_img,cv2.bitwise_and(new_img,new_img,mask=final)))
            cv2.imwrite('data/Segmented/'+str(folder)+'/S-'+db.names[folder][j],res)
    if remove_flag:
        rework(folder,j,db,final,means,stds,new_img,rw=rw)

# %%
dbpath = '../Database/Bales/'

db = balefiles(dbpath)
db.getall()
# db.paths
# db.names
# db.pathfiles

# %%
# %%time
folder = {}
for folder in range(len(db.paths)):
    try:
        makedirs('data/'+str(folder)+'/masks/')
    except:
        pass
    try:
        makedirs('data/Segmented/'+str(folder))
    except:
        pass
    for i in range(len(db.pathfiles[folder])):
        print(db.pathfiles[folder][i],end='\t')
        sample = db.pathfiles[folder][i]
        img = cv2.imread(sample)
        print('Extracting...',end='\t')
        final = extract_bales(img)
        print('DONE!',end='')
        print('Saving...',end='\t')
        np.save('data/'+str(folder)+'/masks/M-'+db.names[folder][i][:-4],final)
        res = np.hstack((img,cv2.bitwise_and(img,img,mask=final)))
        cv2.imwrite('data/Segmented/'+str(folder)+'/S-'+db.names[folder][i],res)
        print('DONE!')
# Out:
# ../Database/Bales/0/DJI_0523.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0524.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0525.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0526.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0527.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0528.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0529.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0530.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0531.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0532.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0533.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0534.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0535.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0536.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0537.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0538.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0539.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0540.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0541.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0542.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0543.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0544.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0545.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0546.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0547.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0548.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0549.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0550.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0551.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0552.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0553.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0554.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0555.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0556.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0557.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0558.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0559.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0560.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0561.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0562.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0563.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0564.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0565.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0566.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0567.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0568.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0569.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0570.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0571.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0572.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0573.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0574.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0575.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0576.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0577.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0578.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0579.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0580.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0581.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0582.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0583.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0584.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0585.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0586.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0587.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0588.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0589.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0590.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0591.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0592.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0593.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0594.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0595.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0596.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0597.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0598.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0599.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0600.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0601.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0602.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0603.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0604.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0605.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0606.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0607.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0608.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0609.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0610.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0611.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0612.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0613.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0614.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0615.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0616.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0617.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0618.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0619.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0620.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0621.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0622.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0623.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0624.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0625.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0626.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0627.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0628.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0629.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0630.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0631.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0632.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0633.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0634.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0635.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0636.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0637.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0638.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0639.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0640.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0641.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0642.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0643.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0644.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0645.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0646.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0647.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0648.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0649.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0650.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0651.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0652.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0653.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/0/DJI_0654.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0290.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0291.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0292.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0293.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0294.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0295.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0296.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0297.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0298.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0299.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0300.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0301.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0302.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0303.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0304.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0305.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0306.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0307.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0308.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0309.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0310.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0311.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0312.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0313.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0314.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0315.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0316.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0317.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0318.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0319.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0320.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0321.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0322.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0323.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0324.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0325.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0326.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0327.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0328.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0329.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0330.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0331.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0332.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0333.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0334.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0335.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0336.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0337.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0338.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0339.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0340.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0341.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/1/DJI_0342.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0852.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0853.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0854.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0855.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0856.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0857.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0858.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0859.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0860.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0861.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0862.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0863.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0864.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0865.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0866.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0867.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0868.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0869.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0870.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0871.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0872.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0873.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0874.JPG	Extracting...	DONE!Saving...	DONE!
# ../Database/Bales/2/DJI_0875.JPG	Extracting...	DONE!Saving...

# %%
test_m = 'data/'+db.paths[1]+'/masks/M-'+db.names[1][0][:-3]+'npy'
test_o = 'data/'+db.paths[1]+'/'+db.names[1][0]
img_o = cv2.imread(test_o)
img_o = extract_bales(img_o)
img_1 = np.load(test_m)
plt.figure()
plt.imshow(img_1,cmap='gray')
plt.figure()
plt.imshow(img_o,cmap='gray')

# %%
image_label_overlay = label2rgb(label_image, image=img, bg_label=0)
plt.imshow(image_label_overlay)

# %%
label_image = label(img_1)
plt.imshow(label_image)
